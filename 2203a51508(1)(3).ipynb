# %%
import pandas as pd
d=pd.read_csv('/content/2203a51508.csv')
print(d)
# Out:
#    ID Name                                                      Unnamed: 2  \
# 0   1                          Chocolate milkshake                     NaN
# 1   2  Vanilla  milkshake                            ...               NaN
# 2   3  Strawberry milkshake                          ...               NaN
# 3   4  Banana milkshake                              ...               NaN
# 4   5  Cookies & Cream milkshake                     ...               NaN
# 5   6  Peanut Butter milkshake                       ...               NaN
# 6   7  Mint Chocolate Chip milkshake                 ...               NaN
# 7   8  Salted Caramel milkshake                      ...               NaN
# 8   9  Coffee milkshake                              ...               NaN
# 9  10                           Oreo milkshake                         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# ...

# %%
d=pd.read_excel('/content/2203a51508.xlsx')
print(d)
# Out:
#    ID Name                                                      Unnamed: 2  \
# 0   1                          Chocolate milkshake                     NaN
# 1   2  Vanilla  milkshake                            ...               NaN
# 2   3  Strawberry milkshake                          ...               NaN
# 3   4  Banana milkshake                              ...               NaN
# 4   5  Cookies & Cream milkshake                     ...               NaN
# 5   6  Peanut Butter milkshake                       ...               NaN
# 6   7  Mint Chocolate Chip milkshake                 ...               NaN
# 7   8  Salted Caramel milkshake                      ...               NaN
# 8   9  Coffee milkshake                              ...               NaN
# 9  10                           Oreo milkshake                         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# ...

# %%
d=pd.read_csv('/content/2203A51508.tsv')
print(d)
# Out:
#   ID\tName                                                    \t\t\t\t\tQuantity
# 0  1\tChocolate milkshake      \t\t\t\t\t        ...
# 1  2\tVanilla  milkshake                         ...
# 2  3\tStrawberry milkshake                       ...
# 3  4\tBanana milkshake                           ...
# 4  5\tCookies & Cream milkshake                  ...
# 5  6\tPeanut Butter milkshake                    ...
# 6  7\tMint Chocolate Chip milkshake              ...
# 7  8\tSalted Caramel milkshake                   ...
# 8  9\tCoffee milkshake                           ...
# 9  10\tOreo milkshake          \t\t\t\t\t        ...
